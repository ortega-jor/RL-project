# %% [markdown]
# ### Import libraries

# %%
import os
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.monitor import Monitor

# %% [markdown]
# ### Make environments monitoring rewards

# %%
# Ensure MuJoCo is using the correct OpenGL backend
os.environ["MUJOCO_GL"] = "glfw"

def make_env(rank):
    def _init():
        env = gym.make("Walker2d-v5", render_mode=None)  # No GUI during training
        env = Monitor(env, filename=f"./logs/monitor_{rank}.csv")  # Logs per env)
        return env
    return _init

num_envs = 4  
env = SubprocVecEnv([make_env(i) for i in range(num_envs)])

# %% [markdown]
# ### Define PPO policy using SB3. Start learning and save results

# %%
ppo_model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=64,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    clip_range_vf=0.2,
    ent_coef=0.01,
    vf_coef=0.5,
    target_kl=0.05,
    verbose=1,
    device="cpu",
    tensorboard_log="./ppo_logs/Tests_10M"
    )

time_steps = 10_000_000 # Adjust based on your training time
ppo_model.learn(total_timesteps=time_steps, tb_log_name="ModifiedTorquesRewards2_10M")

ppo_model.save("ppo_SB3_ModifiedTorquesRewards2_10Msteps") 

env.close()
# Out:
# Using cpu device
# Logging to ./ppo_logs/Tests_10M\ModifiedTorquesRewards2_10M_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | 7.48     |
# | time/              |          |
# |    fps             | 2012     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.4        |
# |    ep_rew_mean          | 15.7        |
# | time/                   |             |
# |    fps                  | 1069        |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019793052 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.47       |
# |    explained_variance   | 0.0308      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0325     |
# |    std                  | 0.991       |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 39.8       |
# |    ep_rew_mean          | 30.9       |
# | time/                   |            |
# |    fps                  | 912        |
# |    iterations           | 3          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01815734 |
# |    clip_fraction        | 0.242      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -8.42      |
# |    explained_variance   | 0.0595     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.8       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0315    |
# |    std                  | 0.983      |
# |    value_loss           | 59.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59          |
# |    ep_rew_mean          | 56.1        |
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.017273499 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.0516      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.978       |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 115         |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 5           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014594046 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0.0451      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 101         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.971       |
# |    value_loss           | 220         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 6           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.013388975 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0.0568      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.02       |
# |    std                  | 0.973       |
# |    value_loss           | 379         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 7           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011867242 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.33       |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 231         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.971       |
# |    value_loss           | 449         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 809         |
# |    iterations           | 8           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.012857614 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.34       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 233         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.972       |
# |    value_loss           | 507         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 188         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 9           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.012530541 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.976       |
# |    value_loss           | 491         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 192         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 10          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011993112 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.35       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.974       |
# |    value_loss           | 437         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 797         |
# |    iterations           | 11          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.011364639 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.36       |
# |    explained_variance   | 0.373       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 233         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.976       |
# |    value_loss           | 451         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 193          |
# |    ep_rew_mean          | 291          |
# | time/                   |              |
# |    fps                  | 796          |
# |    iterations           | 12           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0115620475 |
# |    clip_fraction        | 0.139        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 0.2          |
# |    entropy_loss         | -8.4         |
# |    explained_variance   | 0.357        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 317          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.016       |
# |    std                  | 0.982        |
# |    value_loss           | 550          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 13          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.013217645 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 256         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.981       |
# |    value_loss           | 483         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 300         |
# | time/                   |             |
# |    fps                  | 788         |
# |    iterations           | 14          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.012432848 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.4        |
# |    explained_variance   | 0.236       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 295         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.981       |
# |    value_loss           | 559         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 300         |
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 15          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.012495782 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.39       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 255         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0162     |
# |    std                  | 0.979       |
# |    value_loss           | 522         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 16          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.013023603 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.4        |
# |    explained_variance   | 0.0632      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 300         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.98        |
# |    value_loss           | 550         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | 310         |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 17          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.013089575 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.0521      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 268         |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.984       |
# |    value_loss           | 540         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | 305         |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 18          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012852496 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.41       |
# |    explained_variance   | 0.0432      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.981       |
# |    value_loss           | 527         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 302         |
# | time/                   |             |
# |    fps                  | 741         |
# |    iterations           | 19          |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.012885833 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.43       |
# |    explained_variance   | 0.0261      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 249         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.989       |
# |    value_loss           | 515         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 20          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.013131552 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.49       |
# |    explained_variance   | 0.0178      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 234         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.998       |
# |    value_loss           | 513         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 162         |
# |    ep_rew_mean          | 286         |
# | time/                   |             |
# |    fps                  | 725         |
# |    iterations           | 21          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.013432264 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.52       |
# |    explained_variance   | 0.00822     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 253         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 1           |
# |    value_loss           | 526         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 22          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.012179956 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.55       |
# |    explained_variance   | 0.00524     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 234         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 1.01        |
# |    value_loss           | 518         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 712         |
# |    iterations           | 23          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.012860764 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.62       |
# |    explained_variance   | 0.00277     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 265         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 1.02        |
# |    value_loss           | 497         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 282         |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 24          |
# |    time_elapsed         | 277         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.014376396 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.68       |
# |    explained_variance   | 0.00212     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 224         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 1.03        |
# |    value_loss           | 486         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 158       |
# |    ep_rew_mean          | 281       |
# | time/                   |           |
# |    fps                  | 706       |
# |    iterations           | 25        |
# |    time_elapsed         | 290       |
# |    total_timesteps      | 204800    |
# | train/                  |           |
# |    approx_kl            | 0.0130051 |
# |    clip_fraction        | 0.148     |
# |    clip_range           | 0.2       |
# |    clip_range_vf        | 0.2       |
# |    entropy_loss         | -8.7      |
# |    explained_variance   | 0.000535  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 241       |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0167   |
# |    std                  | 1.03      |
# |    value_loss           | 488       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 26          |
# |    time_elapsed         | 303         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.013851261 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.72       |
# |    explained_variance   | 0.000496    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 237         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 1.04        |
# |    value_loss           | 480         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 699         |
# |    iterations           | 27          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.012892211 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.76       |
# |    explained_variance   | 0.000416    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 218         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 1.04        |
# |    value_loss           | 472         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 28          |
# |    time_elapsed         | 328         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.013324238 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.78       |
# |    explained_variance   | 0.00037     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 224         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 1.05        |
# |    value_loss           | 463         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 275          |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 29           |
# |    time_elapsed         | 342          |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0140164085 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 0.2          |
# |    entropy_loss         | -8.81        |
# |    explained_variance   | 0.000242     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 234          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0173      |
# |    std                  | 1.06         |
# |    value_loss           | 475          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 30          |
# |    time_elapsed         | 355         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.013815984 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.87       |
# |    explained_variance   | 0.000184    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 1.06        |
# |    value_loss           | 455         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 154        |
# |    ep_rew_mean          | 276        |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 31         |
# |    time_elapsed         | 364        |
# |    total_timesteps      | 253952     |
# | train/                  |            |
# |    approx_kl            | 0.01343894 |
# |    clip_fraction        | 0.149      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -8.91      |
# |    explained_variance   | 0.000151   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 213        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0158    |
# |    std                  | 1.07       |
# |    value_loss           | 451        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 32          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.015092639 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -8.95       |
# |    explained_variance   | 0.00017     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 205         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 1.08        |
# |    value_loss           | 442         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 33          |
# |    time_elapsed         | 382         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.014427743 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.01       |
# |    explained_variance   | 8.04e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 231         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 1.09        |
# |    value_loss           | 452         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 34          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.014461274 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.08       |
# |    explained_variance   | 2.34e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 234         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 1.1         |
# |    value_loss           | 438         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 716         |
# |    iterations           | 35          |
# |    time_elapsed         | 400         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.013781175 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.08       |
# |    explained_variance   | 6.41e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 201         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 1.1         |
# |    value_loss           | 430         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 272         |
# | time/                   |             |
# |    fps                  | 720         |
# |    iterations           | 36          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.014337943 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.14       |
# |    explained_variance   | 3.56e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 222         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 1.11        |
# |    value_loss           | 422         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 151        |
# |    ep_rew_mean          | 273        |
# | time/                   |            |
# |    fps                  | 724        |
# |    iterations           | 37         |
# |    time_elapsed         | 418        |
# |    total_timesteps      | 303104     |
# | train/                  |            |
# |    approx_kl            | 0.01488848 |
# |    clip_fraction        | 0.163      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -9.21      |
# |    explained_variance   | 3.09e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 208        |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0176    |
# |    std                  | 1.13       |
# |    value_loss           | 428        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 38          |
# |    time_elapsed         | 427         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.013769502 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.24       |
# |    explained_variance   | 3.49e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 196         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 1.13        |
# |    value_loss           | 410         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 39          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.015511399 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.3        |
# |    explained_variance   | -2.38e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 1.14        |
# |    value_loss           | 410         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 40          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.015428418 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.36       |
# |    explained_variance   | 1.2e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 1.16        |
# |    value_loss           | 410         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 41           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0141152255 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 0.2          |
# |    entropy_loss         | -9.41        |
# |    explained_variance   | 8.4e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 209          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0204      |
# |    std                  | 1.16         |
# |    value_loss           | 405          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 151        |
# |    ep_rew_mean          | 274        |
# | time/                   |            |
# |    fps                  | 741        |
# |    iterations           | 42         |
# |    time_elapsed         | 464        |
# |    total_timesteps      | 344064     |
# | train/                  |            |
# |    approx_kl            | 0.01508334 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -9.47      |
# |    explained_variance   | 1.08e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 172        |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0181    |
# |    std                  | 1.18       |
# |    value_loss           | 402        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 43          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 352256      |
# | train/                  |             |
# |    approx_kl            | 0.014921479 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.55       |
# |    explained_variance   | -2.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 185         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 1.19        |
# |    value_loss           | 397         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 748         |
# |    iterations           | 44          |
# |    time_elapsed         | 481         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.015520883 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.6        |
# |    explained_variance   | 5.48e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 184         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 1.2         |
# |    value_loss           | 396         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 150         |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 45          |
# |    time_elapsed         | 491         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.015709274 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.65       |
# |    explained_variance   | -5.84e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 229         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 1.21        |
# |    value_loss           | 391         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 46          |
# |    time_elapsed         | 501         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.015599766 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.7        |
# |    explained_variance   | -6.32e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 170         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 1.22        |
# |    value_loss           | 393         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 274         |
# | time/                   |             |
# |    fps                  | 753         |
# |    iterations           | 47          |
# |    time_elapsed         | 510         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.015158242 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.77       |
# |    explained_variance   | -1.01e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 236         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0202     |
# |    std                  | 1.24        |
# |    value_loss           | 385         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 48           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0148534365 |
# |    clip_fraction        | 0.167        |
# |    clip_range           | 0.2          |
# |    clip_range_vf        | 0.2          |
# |    entropy_loss         | -9.82        |
# |    explained_variance   | -2.03e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0192      |
# |    std                  | 1.25         |
# |    value_loss           | 380          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 49          |
# |    time_elapsed         | 528         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.014355497 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.87       |
# |    explained_variance   | -6.91e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 189         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 1.26        |
# |    value_loss           | 370         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 154         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 50          |
# |    time_elapsed         | 538         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.014599675 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -9.93       |
# |    explained_variance   | -1.63e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 172         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 1.27        |
# |    value_loss           | 380         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 761         |
# ...
# | train/                  |             |
# |    approx_kl            | 0.010864747 |
# |    clip_fraction        | 0.0896      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -37.9       |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 798         |
# |    n_updates            | 12037       |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 154         |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 527         |
# |    ep_rew_mean          | 1.59e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1206        |
# |    time_elapsed         | 14928       |
# |    total_timesteps      | 9879552     |
# | train/                  |             |
# |    approx_kl            | 0.010382656 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -37.9       |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 188         |
# |    n_updates            | 12047       |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 155         |
# |    value_loss           | 1.1e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 1.62e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1207        |
# |    time_elapsed         | 14940       |
# |    total_timesteps      | 9887744     |
# | train/                  |             |
# |    approx_kl            | 0.009807626 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -37.9       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 249         |
# |    n_updates            | 12057       |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 156         |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 541         |
# |    ep_rew_mean          | 1.63e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1208        |
# |    time_elapsed         | 14954       |
# |    total_timesteps      | 9895936     |
# | train/                  |             |
# |    approx_kl            | 0.008534406 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38         |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 339         |
# |    n_updates            | 12067       |
# |    policy_gradient_loss | -0.00844    |
# |    std                  | 156         |
# |    value_loss           | 875         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 551         |
# |    ep_rew_mean          | 1.67e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1209        |
# |    time_elapsed         | 14967       |
# |    total_timesteps      | 9904128     |
# | train/                  |             |
# |    approx_kl            | 0.011988549 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38         |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 237         |
# |    n_updates            | 12077       |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 157         |
# |    value_loss           | 927         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 568         |
# |    ep_rew_mean          | 1.72e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1210        |
# |    time_elapsed         | 14980       |
# |    total_timesteps      | 9912320     |
# | train/                  |             |
# |    approx_kl            | 0.010304983 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38         |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 437         |
# |    n_updates            | 12087       |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 158         |
# |    value_loss           | 821         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 587         |
# |    ep_rew_mean          | 1.78e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1211        |
# |    time_elapsed         | 14994       |
# |    total_timesteps      | 9920512     |
# | train/                  |             |
# |    approx_kl            | 0.010722116 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38         |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 694         |
# |    n_updates            | 12097       |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 160         |
# |    value_loss           | 1.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 565         |
# |    ep_rew_mean          | 1.69e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1212        |
# |    time_elapsed         | 15008       |
# |    total_timesteps      | 9928704     |
# | train/                  |             |
# |    approx_kl            | 0.009257849 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.1       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 898         |
# |    n_updates            | 12107       |
# |    policy_gradient_loss | -0.00978    |
# |    std                  | 161         |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 541        |
# |    ep_rew_mean          | 1.61e+03   |
# | time/                   |            |
# |    fps                  | 661        |
# |    iterations           | 1213       |
# |    time_elapsed         | 15022      |
# |    total_timesteps      | 9936896    |
# | train/                  |            |
# |    approx_kl            | 0.01136996 |
# |    clip_fraction        | 0.0885     |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -38.1      |
# |    explained_variance   | 0.816      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 436        |
# |    n_updates            | 12117      |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 162        |
# |    value_loss           | 1.19e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 532         |
# |    ep_rew_mean          | 1.58e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1214        |
# |    time_elapsed         | 15037       |
# |    total_timesteps      | 9945088     |
# | train/                  |             |
# |    approx_kl            | 0.010471772 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.1       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 923         |
# |    n_updates            | 12127       |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 162         |
# |    value_loss           | 1.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 494        |
# |    ep_rew_mean          | 1.45e+03   |
# | time/                   |            |
# |    fps                  | 661        |
# |    iterations           | 1215       |
# |    time_elapsed         | 15051      |
# |    total_timesteps      | 9953280    |
# | train/                  |            |
# |    approx_kl            | 0.00929932 |
# |    clip_fraction        | 0.072      |
# |    clip_range           | 0.2        |
# |    clip_range_vf        | 0.2        |
# |    entropy_loss         | -38.1      |
# |    explained_variance   | 0.749      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 329        |
# |    n_updates            | 12137      |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 163        |
# |    value_loss           | 1.48e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 524         |
# |    ep_rew_mean          | 1.56e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1216        |
# |    time_elapsed         | 15063       |
# |    total_timesteps      | 9961472     |
# | train/                  |             |
# |    approx_kl            | 0.011221485 |
# |    clip_fraction        | 0.0806      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.2       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 289         |
# |    n_updates            | 12147       |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 163         |
# |    value_loss           | 1.36e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | 1.51e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1217        |
# |    time_elapsed         | 15080       |
# |    total_timesteps      | 9969664     |
# | train/                  |             |
# |    approx_kl            | 0.011668543 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.2       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 284         |
# |    n_updates            | 12157       |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 163         |
# |    value_loss           | 1.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 508         |
# |    ep_rew_mean          | 1.51e+03    |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 1218        |
# |    time_elapsed         | 15094       |
# |    total_timesteps      | 9977856     |
# | train/                  |             |
# |    approx_kl            | 0.011072951 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.2       |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 424         |
# |    n_updates            | 12167       |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 163         |
# |    value_loss           | 1.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 511         |
# |    ep_rew_mean          | 1.52e+03    |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 1219        |
# |    time_elapsed         | 15107       |
# |    total_timesteps      | 9986048     |
# | train/                  |             |
# |    approx_kl            | 0.010484159 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.2       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 797         |
# |    n_updates            | 12177       |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 166         |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | 1.45e+03    |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 1220        |
# |    time_elapsed         | 15122       |
# |    total_timesteps      | 9994240     |
# | train/                  |             |
# |    approx_kl            | 0.008977411 |
# |    clip_fraction        | 0.0609      |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.3       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 834         |
# |    n_updates            | 12187       |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 167         |
# |    value_loss           | 1.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 478         |
# |    ep_rew_mean          | 1.39e+03    |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 1221        |
# |    time_elapsed         | 15136       |
# |    total_timesteps      | 10002432    |
# | train/                  |             |
# |    approx_kl            | 0.010354984 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    clip_range_vf        | 0.2         |
# |    entropy_loss         | -38.3       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 392         |
# |    n_updates            | 12197       |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 166         |
# |    value_loss           | 1.35e+03    |
# -----------------------------------------

# %% [markdown]
# ### Load trained model and evaluate

# %%
ppo_model = PPO.load("ppo_SB3_ModifiedTorquesRewards2_10Msteps")
eval_env = gym.make("Walker2d-v5", render_mode="human")

mean_reward, std_reward = evaluate_policy(ppo_model, eval_env, n_eval_episodes=5)
print(f"Mean reward: {mean_reward}, Std reward: {std_reward}")

obs, _ = eval_env.reset()
done = False
while not done:
    action, _states = ppo_model.predict(obs)
    obs, reward, done, truncated, info = eval_env.step(action)
    eval_env.render()

eval_env.close()
# Out:
# Mean reward: 3452.244850087166, Std reward: 646.5295345721495
